# %% [markdown]
# ## Instalação e Importação de Pacotes

# %% [markdown]
# 1. Instalar e Importar os Pacotes Necessários

# %%
import pandas as pd
import geopandas as gpd
from unidecode import unidecode

# %% [markdown]
# 2. Importação dos arquivos xlsx como DataFrames

# %%
df_litogeoquimica_Results = pd.read_excel('./Dados/A24-09381final (litogeoquímica).xlsx',sheet_name='Results')
df_litogeoquimica_QC = pd.read_excel('./Dados/A24-09381final (litogeoquímica).xlsx',sheet_name='QC')
df_amostras= pd.read_excel('./dados/exxonccs (amostras).xlsx')
df_macro= pd.read_excel('./dados/exxonccs (petr. macro).xlsx')
# Out:
# D:\Anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# D:\Anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %% [markdown]
# 3. Visualização dos dados importados

# %%
display(df_litogeoquimica_Results.head(5))
display(df_litogeoquimica_QC.head(5))
display(df_amostras.head(5))
display(df_macro.head(5))
# Out:
#   Report Number: A24-09381 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0   Report Date: 27/8/2024        NaN        NaN        NaN        NaN
# 1           Analyte Symbol       SiO2      Al2O3   Fe2O3(T)        MnO
# 2              Unit Symbol          %          %          %          %
# 3          Detection Limit       0.01       0.01       0.01      0.005
# 4          Analysis Method    FUS-ICP    FUS-ICP    FUS-ICP    FUS-ICP
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 48  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1        MgO        CaO       Na2O        K2O       TiO2  ...          Yb
# 2          %          %          %          %          %  ...         ppm
# 3       0.01       0.01       0.01       0.01      0.001  ...        0.01
# 4    FUS-ICP    FUS-ICP    FUS-ICP    FUS-ICP    FUS-ICP  ...      FUS-MS
#
#   Unnamed: 49 Unnamed: 50 Unnamed: 51 Unnamed: 52 Unnamed: 53 Unnamed: 54  \
# ...
