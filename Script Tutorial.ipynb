# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizFelipe-FF/Script-Tutorial-Python/blob/main/Script%20Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Manipulação e Integração de Dados em Python**

# %% [markdown]
# ##Manipulação de Dados Tabulares

# %% [markdown]
# Este código tem como finalidade auxiliar na manipulação e integração de dados

# %%
Estrutura do Fluxo de Trabalho
Manipulação de Dados Tabulares
Importação de Arquivos Excel

Instalação e carregamento de pacotes (readxl, dplyr).
Leitura de planilhas específicas e visualização de dados.
Padronização e Seleção de Dados

Seleção de colunas relevantes.
Renomeação de colunas para melhorar a legibilidade e evitar erros.
Verificação e Tratamento de Dados

Identificação de duplicatas.
Verificação de integridade das correspondências entre tabelas.
Integração de DataFrames

União de tabelas com colunas comuns utilizando left_join.
Verificação de consistência após a integração.
Exportação de Dados

Salvando os resultados em novos arquivos para uso futuro.

# %% [markdown]
# ##Instalação e Importação de Pacotes

# %% [markdown]
# 1. Instalar e Importar os Pacotes Necessários

# %%
import pandas as pd

# %% [markdown]
# 2. Importação dos arquivos xlsx como DataFrames

# %% [markdown]
# * Copiei meu repositório do github para afcilitar acesso aos dados

# %%
# !git clone https://github.com/LuizFelipe-FF/Script-Tutorial-Python.git
# Out:
# Cloning into 'Script-Tutorial-Python'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 68 (delta 28), reused 14 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (68/68), 169.78 KiB | 2.23 MiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %% [markdown]
# * Utilizei a biblioteca pandas para colocar as tabelas xlsx dentro do python

# %%
df_amostras = pd.read_excel('Script-Tutorial-Python/Dados/exxonccs (amostras).xlsx')
df_macro = pd.read_excel('Script-Tutorial-Python/Dados/exxonccs (petr. macro).xlsx')

# %% [markdown]
# 3. Visualização dos dados importados

# %% [markdown]
# * Após importar as planilhas, é importante verificar se os dados foram carregados corretamente. Utilize as funções print(), display() ou head() para visualizar os dados e verificar a estrutura.

# %%
display(df_amostras.head(5))
display(df_macro.head(5))
# Out:
#   Código da Amostra             Cadastro             Usuário Última Alteração  \
# 0         MR-SS-47A  2024-08-13 14:11:16  Pietra Rocha Gomes              NaN
# 1         MR-SS-47B  2024-07-22 16:44:49  Pietra Rocha Gomes              NaN
# 2         MR-SS-46B  2024-07-22 16:44:19  Pietra Rocha Gomes              NaN
# 3         MR-SS-46A  2024-07-22 16:43:49  Pietra Rocha Gomes              NaN
# 4          MR-SS-45  2024-07-22 16:43:33  Pietra Rocha Gomes              NaN
#
#      Área     Ponto  Local de Coleta Tipo(s) de Amostra   Origem  Citação  \
# 0  Área 2  MR-SS-47              NaN     Amostra de Mão  Projeto      NaN
# 1  Área 2  MR-SS-47              NaN     Amostra de Mão  Projeto      NaN
# 2  Área 2  MR-SS-46              NaN     Amostra de Mão  Projeto      NaN
# 3  Área 2  MR-SS-46              NaN     Amostra de Mão  Projeto      NaN
# 4  Área 2  MR-SS-45              NaN     Amostra de Mão  Projeto      NaN
#
#    DOI  Coordenadas (Lat:Long)  Coordenadas UTM (N:E, Fuso, Hem.)  \
# 0  NaN                     NaN                                NaN
# 1  NaN                     NaN                                NaN
# 2  NaN                     NaN                                NaN
# 3  NaN                     NaN                                NaN
# 4  NaN                     NaN                                NaN
#
#    Datum Geodésico
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#               Cadastro                         Usuário  \
# 0  2024-11-18 15:24:58              Pietra Rocha Gomes
# 1  2024-11-18 07:55:02              Pietra Rocha Gomes
# 2  2024-11-04 13:12:17  Lara Evelyn de Lima da Pascoa
# 3  2024-11-04 12:37:42  Lara Evelyn de Lima da Pascoa
# 4  2024-10-21 16:01:24       Guilherme Freicho Ribeiro
#
#                                  Última Alteração   Origem  Citação  DOI  \
# 0                                             NaN  Projeto      NaN  NaN
# 1  18/11/24 14:46 - pietraferreirarocha@gmail.com  Projeto      NaN  NaN
# 2            04/11/24 13:33 - Larapascoa@ufrrj.br  Projeto      NaN  NaN
# 3            04/11/24 12:42 - Larapascoa@ufrrj.br  Projeto      NaN  NaN
# 4        13/11/24 12:03 - gui.freicho@hotmail.com  Projeto      NaN  NaN
#
#   Código da Amostra Amostra selecionada para laminação?  \
# 0         CD-BV-19A                        NÃO DEFINIDO
# 1         CD-BV-19D                        NÃO DEFINIDO
# 2         CD-BV-13A                                 SIM
# 3          CD-BV-11                                 SIM
# 4         VD-BV-35A                        NÃO DEFINIDO
#
#        Grau de Alteração      Natureza  ...  Classificação  \
# 0  PARCIALMENTE ALTERADO  NÃO COERENTE  ...       PEPERITO
# 1  PARCIALMENTE ALTERADO  NÃO COERENTE  ...       PEPERITO
# 2               ALTERADO  NÃO COERENTE  ...       PEPERITO
# 3  PARCIALMENTE ALTERADO  NÃO COERENTE  ...       PEPERITO
# 4  PARCIALMENTE ALTERADO  NÃO COERENTE  ...       PEPERITO
#
#                                       Observações.28 Imagens e Arquivos  \
# 0   A rocha é não coerente, anisotrópica, hipocri...                  0
# 1  A rocha é não coerente, anisotrópica, hipocris...                  0
# 2  A rocha é não-coerente, hipocristalina, clasto...                  5
# 3  A rocha é não-coerente, hipocristalina, matriz...                  4
# 4  A rocha é anisotrópica, hipocristalina, não co...                  4
#
#                                          Unnamed: 76  \
# 0                                                NaN
# 1                                                NaN
# 2  http://www.labmeg.com/projetos/15/2563-13-CD-B...
# 3  http://www.labmeg.com/projetos/15/2562-f1-CD-B...
# 4  http://www.labmeg.com/projetos/15/2560-fd-VD-B...
#
#                                          Unnamed: 77  \
# 0                                                NaN
# 1                                                NaN
# 2  http://www.labmeg.com/projetos/15/2563-8f-CD-B...
# 3  http://www.labmeg.com/projetos/15/2562-91-CD-B...
# 4  http://www.labmeg.com/projetos/15/2560-8a-VD-B...
#
#                                          Unnamed: 78  \
# 0                                                NaN
# 1                                                NaN
# 2  http://www.labmeg.com/projetos/15/2563-3f-CD-B...
# 3  http://www.labmeg.com/projetos/15/2562-84-CD-B...
# 4  http://www.labmeg.com/projetos/15/2560-b0-VD-B...
#
#                                          Unnamed: 79  \
# 0                                                NaN
# 1                                                NaN
# 2  http://www.labmeg.com/projetos/15/2563-99-CD-B...
# 3  http://www.labmeg.com/projetos/15/2562-6a-CD-B...
# 4  http://www.labmeg.com/projetos/15/2560-25-VD-B...
#
#                                          Unnamed: 80 Unnamed: 81 Unnamed: 82
# 0                                                NaN         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2  http://www.labmeg.com/projetos/15/2563-01-CD-B...         NaN         NaN
# 3                                                NaN         NaN         NaN
# 4                                                NaN         NaN         NaN
#
# [5 rows x 83 columns]

# %% [markdown]
# #Seleção de Colunas Específicas de um DataFrame

# %% [markdown]
# 1. Seleção das Colunas

# %% [markdown]
# Para selecionar colunas específicas em um DataFrame, use duas sequências de colchetes '[]'. A primeira sequência é usada para acessar o DataFrame, e a segunda para especificar uma lista de colunas que você deseja selecionar.

# %% [markdown]
# * Planilha amostras: (Código da Amostra, Área, Ponto)

# %%
df_amostras = df_amostras[['Código da Amostra', 'Área', 'Ponto']]

# %% [markdown]
# * Planilha macro: (Código da Amostra, Classificação, Grau de Alteração, Natureza)

# %%
df_macro = df_macro[['Código da Amostra', 'Classificação', 'Grau de Alteração', 'Natureza']]
# theresa colocou coluna 'Outras Estruturas...36' não encontrei

# %% [markdown]
# 2. Renomeação

# %% [markdown]
# * Evitar acentos, espaços e caracteres especiais em nomes de colunas é uma boa prática de programação, pois aumenta a compatibilidade e legibilidade do código.

# %%
df_amostras = df_amostras.rename(columns={'Código da Amostra':'id_amostra'})
df_amostras = df_amostras.rename(columns={'Ponto':'id_pt'})
df_amostras = df_amostras.rename(columns={'Área':'area'})

# %%
df_macro = df_macro.rename(columns={'Código da Amostra':'id_amostra'})
df_macro = df_macro.rename(columns={'Classificação':'lito'})
df_macro = df_macro.rename(columns={'Grau de Alteração':'grau_alt'})
df_macro = df_macro.rename(columns={'Natureza':'natureza'})

# %% [markdown]
# #Integrando os DataFrames

# %% [markdown]
# * Quando dois DataFrames compartilham uma coluna em comum, podemos uni-los para integrar informações.

# %% [markdown]
# 1. Verificação de Duplicadas em amostras e macro

# %%
duplicatas_amostras = df_amostras[df_amostras.duplicated(subset=['id_amostra'])]
print(duplicatas_amostras)
# Out:
# Empty DataFrame
# Columns: [id_amostra, area, id_pt]
# Index: []

# %%
duplicatas_macro = df_macro[df_macro.duplicated(subset=['id_amostra'])]
print(duplicatas_macro)
# Out:
#     id_amostra      lito               grau_alt  natureza
# 111  CD-BV-19A  PEPERITO  PARCIALMENTE ALTERADO  COERENTE

# %% [markdown]
# 2. Verificar se todas as amostras de macro estão em amostras

# %%
faltantes = df_macro[~df_macro['id_amostra'].isin(df_amostras['id_amostra'])]

# %% [markdown]
# 3. Juntando os DataFrames

# %%
amostras_macro = pd.merge(df_amostras, df_macro, on = 'id_amostra', how = 'left')

# %% [markdown]
# 4. Verificar o Resultado da Junção

# %% [markdown]
# * Após a junção, o DataFrame amostras_macro conterá todas as colunas de amostras e as colunas adicionais de macro onde houver correspondência pela coluna id_amostra

# %%
amostras_macro.head(5)
# Out:
#   id_amostra    area     id_pt lito grau_alt natureza
# 0  MR-SS-47A  Área 2  MR-SS-47  NaN      NaN      NaN
# 1  MR-SS-47B  Área 2  MR-SS-47  NaN      NaN      NaN
# 2  MR-SS-46B  Área 2  MR-SS-46  NaN      NaN      NaN
# 3  MR-SS-46A  Área 2  MR-SS-46  NaN      NaN      NaN
# 4   MR-SS-45  Área 2  MR-SS-45  NaN      NaN      NaN

# %% [markdown]
# ##Exportando o novo DataFrame em XLSX

# %%
amostras_macro.to_excel('/content/Script-Tutorial-Python/Dados/amostras_macro.xlsx')

# %% [markdown]
# ##**Transformando o XLSX em Shapefile**

# %%
import geopandas as gpd

# %%
shp_pontos = gpd.read_file('/pontos.shp')
shp_amostras = gpd.read_file('/amostras.shp')

# %%
shp_pontos.head(5)
# Out:
#    FID Código do P  Latitude  Longitude  Northing (N  Easting (E)  Fuso  \
# 0    0    RP-MG-47       -21        -47          766          219    23
# 1    1    RP-MG-46       -21        -47          766          219    23
# 2    2    RP-MG-45       -21        -47          766          219    23
# 3    3    RP-MG-44       -21        -47          764          211    23
# 4    4    RP-MG-43       -21        -47          764          211    23
#
#    Altitude (m    Área                                           Amostras  \
# 0            0  Área 3                      RP-MG-47A,RP-MG-47B,RP-MG-47C
# 1            0  Área 3                      RP-MG-46A,RP-MG-46B,RP-MG-46C
# 2            0  Área 3  RP-MG-45A,RP-MG-45A,RP-MG-45B,RP-MG-45C,RP-MG-...
# 3            0  Área 3                                           RP-MG-44
# 4            0  Área 3            RP-MG-43A,RP-MG-43B,RP-MG-43C,RP-MG-43D
#
#   Petr. Macro Petr. Micro Geoquímica Geocron  \
# 0         Não         Não        Não     Não
# 1         Não         Não        Não     Não
# 2         Não         Não        Não     Não
# 3         Não         Não        Não     Não
# 4         Não         Não        Não     Não
#
#                           Relatório                     geometry
# 0  http://www.labmeg.com/ponto/1104  POINT (-47.70054 -21.08007)
# 1  http://www.labmeg.com/ponto/1103  POINT (-47.69968 -21.07948)
# 2  http://www.labmeg.com/ponto/1102  POINT (-47.69964 -21.07927)
# 3  http://www.labmeg.com/ponto/1101  POINT (-47.78251 -21.25393)
# 4  http://www.labmeg.com/ponto/1100   POINT (-47.7799 -21.25121)

# %%
shp_pontos = shp_pontos.rename(columns={'Código do P':'id_pt'})

# %%
shp_pontos = shp_pontos[['id_pt','Latitude','Longitude','Northing (N','Easting (E)','Fuso','geometry']]

# %%
shp_pontos
# Out:
#         id_pt  Latitude  Longitude  Northing (N  Easting (E)  Fuso  \
# 0    RP-MG-47       -21        -47          766          219    23
# 1    RP-MG-46       -21        -47          766          219    23
# 2    RP-MG-45       -21        -47          766          219    23
# 3    RP-MG-44       -21        -47          764          211    23
# 4    RP-MG-43       -21        -47          764          211    23
# ..        ...       ...        ...          ...          ...   ...
# 147  VD-BV-05       -27        -51          699          450    22
# 148  VD-BV-04       -27        -51          699          450    22
# 149  VD-BV-03       -27        -51          699          450    22
# 150  VD-BV-02       -27        -51          699          450    22
# 151  VD-BV-01       -27        -51          699          450    22
#
#                         geometry
# 0    POINT (-47.70054 -21.08007)
# 1    POINT (-47.69968 -21.07948)
# 2    POINT (-47.69964 -21.07927)
# 3    POINT (-47.78251 -21.25393)
# 4     POINT (-47.7799 -21.25121)
# ..                           ...
# 147  POINT (-51.49464 -27.15884)
# 148  POINT (-51.49495 -27.15906)
# 149   POINT (-51.4956 -27.15865)
# 150  POINT (-51.49601 -27.15815)
# 151   POINT (-51.4957 -27.15776)
#
# [152 rows x 7 columns]

# %%
amostras_macro_shp = pd.merge(amostras_macro, shp_pontos, on = 'id_pt', how = 'left')

# %%
amostras_espacializadas = amostras_macro_shp[['id_amostra','id_pt','area','lito','grau_alt','natureza','Latitude','Longitude','Fuso','geometry']]

# %%
# Out:
#   id_amostra     id_pt    area lito grau_alt natureza  Latitude  Longitude  \
# 0  MR-SS-47A  MR-SS-47  Área 2  NaN      NaN      NaN       -25        -51
# 1  MR-SS-47B  MR-SS-47  Área 2  NaN      NaN      NaN       -25        -51
# 2  MR-SS-46B  MR-SS-46  Área 2  NaN      NaN      NaN       -25        -51
# 3  MR-SS-46A  MR-SS-46  Área 2  NaN      NaN      NaN       -25        -51
# 4   MR-SS-45  MR-SS-45  Área 2  NaN      NaN      NaN       -25        -51
#
#    Fuso                     geometry
# 0    22   POINT (-51.51611 -25.3036)
# 1    22   POINT (-51.51611 -25.3036)
# 2    22  POINT (-51.50428 -25.32069)
# 3    22  POINT (-51.50428 -25.32069)
# 4    22  POINT (-51.54887 -25.24249)

# %% [markdown]
# definindo como geodataframe

# %%
amostras_espacializadas = gpd.GeoDataFrame(amostras_espacializadas, geometry="geometry")

# %%
amostras_espacializadas.set_crs(epsg=4326)  # conferir se coloquei o crs correto da geometry
# Out:
#     id_amostra     id_pt    area      lito               grau_alt  \
# 0    MR-SS-47A  MR-SS-47  Área 2       NaN                    NaN
# 1    MR-SS-47B  MR-SS-47  Área 2       NaN                    NaN
# 2    MR-SS-46B  MR-SS-46  Área 2       NaN                    NaN
# 3    MR-SS-46A  MR-SS-46  Área 2       NaN                    NaN
# 4     MR-SS-45  MR-SS-45  Área 2       NaN                    NaN
# ..         ...       ...     ...       ...                    ...
# 194  VD-BV-02B  VD-BV-02  Área 1   BASALTO  PARCIALMENTE ALTERADO
# 195  VD-BV-02A  VD-BV-02  Área 1   BASALTO  PARCIALMENTE ALTERADO
# 196  VD-BV-01C  VD-BV-01  Área 1  PEPERITO  PARCIALMENTE ALTERADO
# 197  VD-BV-01B  VD-BV-01  Área 1  PEPERITO  PARCIALMENTE ALTERADO
# 198  VD-BV-01A  VD-BV-01  Área 1   BASALTO  PARCIALMENTE ALTERADO
#
#          natureza  Latitude  Longitude  Fuso                     geometry
# 0             NaN       -25        -51    22   POINT (-51.51611 -25.3036)
# 1             NaN       -25        -51    22   POINT (-51.51611 -25.3036)
# 2             NaN       -25        -51    22  POINT (-51.50428 -25.32069)
# 3             NaN       -25        -51    22  POINT (-51.50428 -25.32069)
# 4             NaN       -25        -51    22  POINT (-51.54887 -25.24249)
# ..            ...       ...        ...   ...                          ...
# 194      COERENTE       -27        -51    22  POINT (-51.49601 -27.15815)
# 195      COERENTE       -27        -51    22  POINT (-51.49601 -27.15815)
# 196  NÃO COERENTE       -27        -51    22   POINT (-51.4957 -27.15776)
# 197  NÃO COERENTE       -27        -51    22   POINT (-51.4957 -27.15776)
# 198      COERENTE       -27        -51    22   POINT (-51.4957 -27.15776)
#
# [199 rows x 10 columns]

# %%
amostras_espacializadas.to_file('/content/Script-Tutorial-Python/Dados/amostras_espacializadas.shp')
# Out:
# /usr/local/lib/python3.11/dist-packages/pyogrio/geopandas.py:662: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
